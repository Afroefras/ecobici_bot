# %%
from ecobici.map import EcoBiciMap
CLIENT_ID = '2199_132ley5lk3404wkk4c4w4ggo48kwcokosogg0k0www84s08gs'
CLIENT_SECRET = '61xytd2ketssok44g4kkckwogkg048gk0ok48sc0k0wgc8scs'
EcoBiciMap(CLIENT_ID, CLIENT_SECRET).get_map()
